# %% [markdown]
# # Tutorial on Wannier Berri : interpolating bands, Berry curvatures, and integrating them
#
# The tutorial will focus on tetrahedron grids
#
# In this tutorial we will see how to compute band energies, Berry curvature, spins and anomalous Hall conductivity  using WannierBerri code and further integrate them over the Brillouin zone to obtain Anomalous Hall conductivity, and other quantities of interest.

# %%
# Preliminary 

# Set environment variables - not mandatory but recommended if you use Parallel()
#import os
#os.environ['OPENBLAS_NUM_THREADS'] = '1' 
#os.environ['MKL_NUM_THREADS'] = '1'


import wannierberri as wberri
import pickle
print (f"Using WannierBerri version {wberri.__version__}")
import numpy as np
import scipy
import matplotlib.pyplot as plt
from termcolor import cprint

#  This block is needed if you run this cell for a second time
#  because one cannot initiate two parallel environments at a time
try:
    parallel.shutdown()   
except NameError:
    pass

# Chiose one of the options:

parallel = wberri.Parallel(num_cpus=4)
#parallel = wberri.Parallel()  # automatic detection 
#parallel = wberri.Serial()
# Out:
# Using WannierBerri version 0.13.5
# 2023-04-12 16:31:33,094	INFO worker.py:1519 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265

# %% [markdown]
# ## Reading the system
#
# In this example we use data stored in the form of a Sparse model. This is a low-precision model, but it describes the valence band of Tellurium reasonably well. Please, update the paths if needed

# %%
param = pickle.load(open("../tests/data/Te_sparse/parameters_Te_high","rb"))
system = wberri.system.SystemSparse(**param)
x=0.259

if False:
    system.symmetrize(
    # positions: positions of each atoms in a unitcell (direct coordinate system)
    positions = np.array([[x, 0 , 1./3],
                    [1-x, 1-x, 0],
                   [0.0, x, 2./3]]),
    # atom_name: name of each atoms, need to correspond to position order.
    atom_name = ['Te','Te','Te'],
    # projections: should be the same with projection card in wannier90.win
    proj = ['Te:s','Te:p'],
    # soc: with soc or spinless
    soc=True,
    # DFT_code: What code was used to complet the DFT calculation. only support VASP and QE now.
    DFT_code='vasp',
    )

generators=["C3z","C2y","TimeReversal"]
system.set_symmetry(generators)
print ("Number of R-vecotors used in the model:",(len(param['matrices']['Ham'].keys())))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1165818/836370354.py in <module>
# ----> 1 param = pickle.load(open("../tests/data/Te_sparse/parameters_Te_high","rb"))
#       2 system = wberri.system.SystemSparse(**param)
#       3 x=0.259
#       4
#       5 if False:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../tests/data/Te_sparse/parameters_Te_high'

# %% [markdown]
# ## Let's plot the bandstructure first

# %%
nodes = {
            "A" : [0, 0, 1/2 ],
            "L" : [0, 1/2, 1/2 ],
            "M" : [0, 1/2, 0 ],
            "G" : [0, 0, 0 ],
            "H" : [1/3, 1/3, 1/2], 
            "K" : [1/3, 1/3, 0 ], 
            None : None
}

tabulators = { "Energy": wberri.calculators.tabulate.Energy(),
               "berry" : wberri.calculators.tabulate.BerryCurvature(kwargs_formula={"external_terms":False}),
             }
tab_all_path = wberri.calculators.TabulatorAll(
                    tabulators,
                    mode = "path")



def plotbands(path,Emin=5,Emax=7):

    result=wberri.run(system, 
                  grid=path, 
                  calculators = {"tabulate" : tab_all_path},
                  parallel = parallel, 
                  print_Kpoints = False)

    path_result = result.results["tabulate"]
    path_result.plot_path_fat( path,
             # quantity="berry",
             # component="z",
              save_file=None,
              Eshift=0,
              Emin=Emin,  Emax=Emax,
              iband=None,
              mode="fatband",
              fatfactor=20,
              cut_k=False, 
              close_fig=False,
              show_fig=False,
              label = "WB"
              )

    plt.legend()
    plt.grid()
    plt.show()
    plt.close()

pth = list("AGHALHKGMK") #+[None,"L","M"]
path=wberri.Path(system,
                 k_nodes=[ nodes[k] for k in pth ],
                 labels=[s for s in pth if s is not None],
                 length=200 )     
    
plotbands(path,Emin=-2,Emax=3)
# Out:
# calculator not described
#
# calculator not described
#
# Calculation along a path - checking calculators for compatibility
# tabulate <wannierberri.calculators.TabulatorAll object at 0x7f8d001fdeb0>
# All calculators are compatible
# Symmetrization switched off for Path
# Grid is regular
# The set of k points is a Path() with 211 points and labels {0: 'A', 17: 'G', 51: 'H', 81: 'A', 107: 'L', 122: 'H', 139: 'K', 169: 'G', 195: 'M', 210: 'K'}
# WARNING : symmetry is not used for a tabulation along path
# generating K_list
# Done
# Done, sum of weights:211.0
# symgroup : None
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa5710ce790>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41ceb6be0>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41d3057f0>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41ceb6160>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4878a60>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4c91880>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4878d00>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4c918b0>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f310967f7c0>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f3109ae1f10>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f310967f310>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f3109ae1eb0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258780730>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f43ac94eac0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258780730>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258beefa0>}
# processing 211 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa5710c3b20>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41ceb6160>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41d3057c0>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41ceb6c40>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa5710c3b20>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41ceb6b80>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41d3057c0>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4878a60>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4c918e0>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4878790>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4c91940>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4878af0>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4c91880>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4878820>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f310967f340>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f3109ae1e20>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f310967f850>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f3109ae15e0>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f310967fbe0>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f3109ae1700>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f310967f820>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258780340>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258beeee0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258780ac0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258beefa0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258780cd0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258beeee0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258780ca0>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4c918b0>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41ceb6850>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41d305760>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41ceb6310>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41d3057f0>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4878370>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4c918e0>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae48787c0>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4c91940>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f3109ae1f10>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f310967fa90>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f3109ae1eb0>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f310967f3a0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258beefa0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258780730>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258beeee0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258780340>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41ceb62e0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258beefa0>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41d305880>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41ceb6340>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41d3058b0>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4878730>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4c91880>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4878760>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f3109ae1e20>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f310967f370>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f3109ae15e0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258780ac0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258beeee0>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41ceb6760>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41d305820>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41ceb6160>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4c918b0>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae48783a0>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4c918e0>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f310967f880>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f3109ae1700>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f310967fa60>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258780cd0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258beefa0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258780ca0>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4878d30>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258beeee0>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41d3057c0>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41ceb6640>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41d305760>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4c91940>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4878d00>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f3109ae1f10>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f310967fc70>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f3109ae1eb0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258780730>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258beefa0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258780340>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41ceb6cd0>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4c91880>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f310967fac0>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41d3057f0>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41ceb67c0>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41d305880>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41ceb6850>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41d3058b0>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4878a60>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4c918b0>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4878790>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4c918e0>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4878af0>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4c91940>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f3109ae1e20>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f310967f190>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f3109ae15e0>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f310967fd30>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f3109ae1700>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258beeee0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258780ac0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258beefa0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258780cd0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258beeee0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258780ca0>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41ceb6310>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41d305820>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41ceb62e0>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41d3057c0>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41ceb6340>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41d305760>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41ceb6850>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4878820>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4c91880>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4878370>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4c918b0>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4878a60>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4c91940>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4878850>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4c918b0>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f310967f7f0>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f3109ae1f10>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f310967f760>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f3109ae1eb0>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f310967f730>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f3109ae1e20>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f310967f7c0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258beefa0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258780730>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258beeee0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258780340>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258beefa0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258780ac0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258beeee0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258780cd0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258beefa0>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41d3057f0>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4878310>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f3109ae15e0>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41ceb6640>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41d305880>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41ceb6340>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41ceb6d00>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa5710c3340>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4c91880>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4878d30>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4c918e0>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4878760>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4878c70>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4cb7eb0>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f310967fca0>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f3109ae1f40>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f310967f730>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f310967fc70>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f3109ac5880>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f310967fd30>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258780ca0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f43ac943700>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258780af0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258780d00>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258bc68b0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f42587803a0>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41ceb6280>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4878cd0>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa5710ce790>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41ceb67c0>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa5710ce790>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdc238032b0>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4878850>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f3109ac58b0>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f310967fac0>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f3109ac58e0>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258bc6850>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258780a60>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258bc6880>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdc238032b0>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f310967f370>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258780cd0>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41ceb6280>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa5710ce790>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa41ceb6820>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4878820>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdc238032b0>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdae4878880>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f3109ac5850>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f310967f7f0>}
# (paralfunc pid=1166068) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f3109ac5880>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258bc6910>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258780730>}
# (paralfunc pid=1166067) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7f4258bc68b0>}
# (paralfunc pid=1166070) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fa5710ce790>}
# (paralfunc pid=1166069) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZpath object at 0x7fdc238032b0>}
# time for processing    211 K-points on   4 processes:     1.4252 ; per K-point          0.0068 ; proc-sec per K-point          0.0270
# time1 =  0.015747785568237305
# Totally processed 211 K-points

# %%
list("asv")
# Out:
# ['a', 's', 'v']

# %% [markdown]
# ## Now have a closer look near H point VBM

# %%
x = 0.15
path=wberri.Path(system,
     k_nodes=[
             np.array(nodes["G"])*x+np.array(nodes["H"])*(1-x),
              nodes["H"],
             np.array(nodes["A"])*x+np.array(nodes["H"])*(1-x),
         None,
             np.array(nodes["L"])*2*x+np.array(nodes["H"])*(1-2*x),
              nodes["H"],
             np.array(nodes["K"])*x+np.array(nodes["H"])*(1-x),
         
             ],
     labels=[r"$\Gamma\leftarrow$","H",r"$\rightarrow$ A",r"L$\leftarrow$","H",r"$\rightarrow$ K"],
     length=1000 ) 

plotbands(path,Emin=5.75,Emax=6.25)
# Out:
# Calculation along a path - checking calculators for compatibility
# tabulate <wannierberri.calculators.TabulatorAll object at 0x7f91641758b0>
# All calculators are compatible
# Symmetrization switched off for Path
# Grid is regular
# The set of k points is a Path() with 84 points and labels {0: '$\\Gamma\\leftarrow$', 26: 'H', 48: 'L$\\leftarrow$', 70: 'H', 83: '$\\rightarrow$ K'}
# WARNING : symmetry is not used for a tabulation along path
# generating K_list
# Done
# Done, sum of weights:84
# symgroup : None
# processing 84 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     84 K-points on   4 processes:     0.5280 ; per K-point          0.0063 ; proc-sec per K-point          0.0251
# time1 =  0.0020890235900878906
# Totally processed 84 K-points

# %% [markdown]
# ## now evaluate the DOS with different grids

# %%
calculators = {}

parameters = dict(
        Efermi = np.linspace(6.0,6.1,201),
        tetra=True
            )

internal = dict(kwargs_formula=dict(external_terms=False))
# Set a grid 
grid = wberri.Grid(system, length=200, NKFFT=[6,6,8] )   # length [ Ang] ~= 2*pi/dk

#calculators ["ohmic"] = wberri.calculators.static.Ohmic_FermiSea(**parameters)
#calculators ["dos"] = wberri.calculators.static.DOS(**parameters)
calculators ["cumdos"] = wberri.calculators.static.CumDOS(**parameters, Emax=6.1, hole_like=True)
calculators ["BD_sea"] = wberri.calculators.static.BerryDipole_FermiSea(**parameters,**internal)
calculators ["BD_sea_hole"] = wberri.calculators.static.BerryDipole_FermiSea(**parameters,**internal,Emax=6.1,hole_like=True)
#calculators ["BD_surf"] = wberri.calculators.static.BerryDipole_FermiSurf(**parameters,**internal)
# Out:
# determining grids from NK=None (<class 'NoneType'>), NKdiv=None (<class 'NoneType'>), NKFFT=[6, 6, 8] (<class 'NoneType'>)
# length=200 was converted into NK=[52 52 34]
# WARNING : the requested k-grid [52 52 34] was adjusted to [54 54 32].
# The grids were set to NKdiv=[9 9 4], NKFFT=[6 6 8], NKtot=[54 54 32]
# Cumulative density of states
#
# Berry curvature dipole (dimensionless)
#
#         | With Fermi sea integral. Eq(29) in `Ref <https://www.nature.com/articles/s41524-021-00498-5>`_
#         | Output: :math:`D_{\beta\delta} = \int [dk] \partial_\beta \Omega_\delta f`
#
# Berry curvature dipole (dimensionless)
#
#         | With Fermi sea integral. Eq(29) in `Ref <https://www.nature.com/articles/s41524-021-00498-5>`_
#         | Output: :math:`D_{\beta\delta} = \int [dk] \partial_\beta \Omega_\delta f`

# %%
result = {}
for length in 300,:
    for grid in [
#        ("tetragonal", wberri.grid.GridTetra(system, length=length, NKFFT=NKFFT ) ),
#        ("trigonal",  wberri.grid.GridTrigonal(system, length=length, NKFFT=NKFFT ) ),
#        ("trigonalH-1",  wberri.grid.GridTrigonalH(system, length=length, NKFFT=1,x=1 ) ),
#        ("trigonalH-0.5",  wberri.grid.GridTrigonalH(system, length=length, NKFFT=1,x=0.5 ) ),
#        ("trigonalH-0.25",  wberri.grid.GridTrigonalH(system, length=length, NKFFT=1,x=0.25 ) ),
        ("trigonalH-0.15",  wberri.grid.GridTrigonalH(system, length=length, NKFFT=1,x=0.15 ) ),
#        ("trigonalH-0.1",  wberri.grid.GridTrigonalH(system, length=length, NKFFT=1,x=0.1 ) ),
 #       ("parallel", wberri.grid.Grid(system, length=length, NKFFT=NKFFT ) ),
                ]:
        result[(length,grid[0])] = wberri.run(system,
            grid=grid[1],
            calculators = calculators,
            parallel=parallel,
            adpt_num_iter=50,
            use_irred_kpt=True,
            symmetrize=True,
            fout_name='Te',
            suffix=f"{grid[0]}-{length}",
            print_Kpoints=False,
            restart=False,
            file_Klist="Klist_ahc.pickle"  # needed to restart a calculation in future
            )
# Out:
# reduced reciprocal lattice :
#  [[1.62891728 0.         0.        ]
#  [0.81445864 1.41068372 0.        ]
#  [0.         0.         1.06063223]]
# using starting tetrahedra with vertices
#  [[[0.33333333 0.33333333 0.5       ]
#   [0.33333333 0.33333333 0.425     ]
#   [0.28333333 0.28333333 0.5       ]
#   [0.38333333 0.23333333 0.5       ]]
#
#  [[0.33333333 0.33333333 0.5       ]
#   [0.33333333 0.33333333 0.575     ]
#   [0.28333333 0.28333333 0.5       ]
#   [0.38333333 0.23333333 0.5       ]]]
# volumes of tetrahedra are [9.375e-05 9.375e-05], total = 0.00018749999999999976
# weights of tetrahedra are [0.001125 0.001125], total = 0.0022499999999999972
# generating starting K_list
# coord in rec.lattice = [   0.333333  ,   0.295833 ,    0.481250 ], refinement level:0, factor = 0.0011249999999999986
# 0.16195084937649687
# coord in rec.lattice = [   0.333333  ,   0.295833 ,    0.518750 ], refinement level:0, factor = 0.0011249999999999986
# 0.16195084937649684
# maximal tetrahedron size for now is 9.374999999999988e-05 (2), we need to refine down to size 3.7694877589978374e-06
# the volume is  0.00018749999999999976 9.374999999999988e-05 9.374999999999988e-05 9.374999999999988e-05
# maximal tetrahedron size for now is 4.687499999999993e-05 (4), we need to refine down to size 3.7694877589978374e-06
# the volume is  0.00018749999999999973 4.687499999999993e-05 4.687499999999993e-05 4.687499999999993e-05
# maximal tetrahedron size for now is 2.3437500000000007e-05 (8), we need to refine down to size 3.7694877589978374e-06
# the volume is  0.0001874999999999998 2.3437499999999967e-05 2.3437500000000007e-05 2.3437499999999973e-05
# maximal tetrahedron size for now is 1.1718750000000004e-05 (16), we need to refine down to size 3.7694877589978374e-06
# the volume is  0.00018749999999999973 1.1718749999999982e-05 1.1718750000000004e-05 1.1718749999999983e-05
# maximal tetrahedron size for now is 5.859375000000001e-06 (32), we need to refine down to size 3.7694877589978374e-06
# the volume is  0.0001874999999999996 5.859374999999991e-06 5.859375000000001e-06 5.859374999999992e-06
# maximal tetrahedron size for now is 2.9296875000000005e-06 (64), we need to refine down to size 3.7694877589978374e-06
# the volume is  0.00018749999999999987 2.9296874999999954e-06 2.9296875000000005e-06 2.929687499999997e-06
# refinement by volume done
# maximal tetrahedron size for now is 0.07053418686997708 (64), we need to refine down to size 0.05923843917544488
# the volume is  0.00018749999999999987 2.9296874999999954e-06 2.9296875000000005e-06 2.929687499999997e-06
# maximal tetrahedron size for now is 0.06930476606619879 (117), we need to refine down to size 0.05923843917544488
# the volume is  0.00018749999999999998 1.4648437499999973e-06 2.9296875000000005e-06 1.6025641025641008e-06
# maximal tetrahedron size for now is 0.06108439728100173 (163), we need to refine down to size 0.05923843917544488
# the volume is  0.00018749999999999998 7.324218749999986e-07 2.9296875000000005e-06 1.1503067484662564e-06
# maximal tetrahedron size for now is 0.05315746199157324 (179), we need to refine down to size 0.05923843917544488
# the volume is  0.00018749999999999976 3.662109374999999e-07 2.9296875000000005e-06 1.0474860335195522e-06
# refinement by size done
# Grid is tetrahedral
# The set of k points is a GridTetra() with 179 tetrahedrons, NKFFT=[1 1 1], NKtot=179
# Done, sum of weights:0.002249999999999995
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 179 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing    179 K-points on   4 processes:     6.0020 ; per K-point          0.0335 ; proc-sec per K-point          0.1341
# time1 =  0.017094135284423828
# time2 =  0.02517104148864746
# sum of weights now :0.002249999999999994
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 8 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing      8 K-points on   4 processes:     0.1218 ; per K-point          0.0152 ; proc-sec per K-point          0.0609
# time1 =  0.0008916854858398438
# time2 =  0.015849828720092773
# sum of weights now :0.002249999999999993
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 8 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing      8 K-points on   4 processes:     0.1226 ; per K-point          0.0153 ; proc-sec per K-point          0.0613
# time1 =  0.0008609294891357422
# time2 =  0.015782594680786133
# sum of weights now :0.002249999999999992
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 8 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing      8 K-points on   4 processes:     0.1707 ; per K-point          0.0213 ; proc-sec per K-point          0.0853
# time1 =  0.002299785614013672
# time2 =  0.02097320556640625
# sum of weights now :0.0022499999999999925
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 8 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing      8 K-points on   4 processes:     0.1446 ; per K-point          0.0181 ; proc-sec per K-point          0.0723
# time1 =  0.0009298324584960938
# time2 =  0.01634955406188965
# sum of weights now :0.002249999999999993
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 10 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     10 K-points on   4 processes:     0.1534 ; per K-point          0.0153 ; proc-sec per K-point          0.0614
# time1 =  0.0011017322540283203
# time2 =  0.013368368148803711
# sum of weights now :0.002249999999999993
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 10 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     10 K-points on   4 processes:     0.1543 ; per K-point          0.0154 ; proc-sec per K-point          0.0617
# time1 =  0.0009570121765136719
# time2 =  0.01291346549987793
# sum of weights now :0.0022499999999999925
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 14 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     14 K-points on   4 processes:     0.3764 ; per K-point          0.0269 ; proc-sec per K-point          0.1075
# time1 =  0.0013196468353271484
# time2 =  0.013927936553955078
# sum of weights now :0.0022499999999999938
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 10 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     10 K-points on   4 processes:     0.1414 ; per K-point          0.0141 ; proc-sec per K-point          0.0565
# time1 =  0.0009503364562988281
# time2 =  0.013090848922729492
# sum of weights now :0.002249999999999993
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 16 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     16 K-points on   4 processes:     0.2209 ; per K-point          0.0138 ; proc-sec per K-point          0.0552
# time1 =  0.0015940666198730469
# time2 =  0.015010356903076172
# sum of weights now :0.0022499999999999916
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 14 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     14 K-points on   4 processes:     0.2152 ; per K-point          0.0154 ; proc-sec per K-point          0.0615
# time1 =  0.0023474693298339844
# time2 =  0.018599748611450195
# sum of weights now :0.0022499999999999916
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 14 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     14 K-points on   4 processes:     0.2258 ; per K-point          0.0161 ; proc-sec per K-point          0.0645
# time1 =  0.0012977123260498047
# time2 =  0.021762609481811523
# sum of weights now :0.0022499999999999916
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 10 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     10 K-points on   4 processes:     0.1465 ; per K-point          0.0146 ; proc-sec per K-point          0.0586
# time1 =  0.0011792182922363281
# time2 =  0.014230012893676758
# sum of weights now :0.0022499999999999916
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 10 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     10 K-points on   4 processes:     0.1379 ; per K-point          0.0138 ; proc-sec per K-point          0.0552
# time1 =  0.0010325908660888672
# time2 =  0.013311624526977539
# sum of weights now :0.0022499999999999903
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 14 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     14 K-points on   4 processes:     0.2165 ; per K-point          0.0155 ; proc-sec per K-point          0.0619
# time1 =  0.0015032291412353516
# time2 =  0.018439769744873047
# sum of weights now :0.002249999999999992
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 16 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     16 K-points on   4 processes:     0.2225 ; per K-point          0.0139 ; proc-sec per K-point          0.0556
# time1 =  0.0017502307891845703
# time2 =  0.014402627944946289
# sum of weights now :0.0022499999999999933
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 16 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     16 K-points on   4 processes:     0.2119 ; per K-point          0.0132 ; proc-sec per K-point          0.0530
# time1 =  0.0016210079193115234
# time2 =  0.01585531234741211
# sum of weights now :0.0022499999999999933
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 16 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     16 K-points on   4 processes:     0.2057 ; per K-point          0.0129 ; proc-sec per K-point          0.0514
# time1 =  0.0015838146209716797
# time2 =  0.013775110244750977
# sum of weights now :0.0022499999999999933
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 14 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     14 K-points on   4 processes:     0.2020 ; per K-point          0.0144 ; proc-sec per K-point          0.0577
# time1 =  0.002100706100463867
# time2 =  0.017052650451660156
# sum of weights now :0.0022499999999999938
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 14 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     14 K-points on   4 processes:     0.1856 ; per K-point          0.0133 ; proc-sec per K-point          0.0530
# time1 =  0.0013079643249511719
# time2 =  0.014523506164550781
# sum of weights now :0.0022499999999999938
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 12 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     12 K-points on   4 processes:     0.1523 ; per K-point          0.0127 ; proc-sec per K-point          0.0508
# time1 =  0.0012519359588623047
# time2 =  0.01511693000793457
# sum of weights now :0.002249999999999994
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 16 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     16 K-points on   4 processes:     0.2167 ; per K-point          0.0135 ; proc-sec per K-point          0.0542
# time1 =  0.0017991065979003906
# time2 =  0.014628887176513672
# sum of weights now :0.002249999999999995
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 14 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     14 K-points on   4 processes:     0.2235 ; per K-point          0.0160 ; proc-sec per K-point          0.0638
# time1 =  0.00131988525390625
# time2 =  0.01979517936706543
# sum of weights now :0.002249999999999996
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 14 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     14 K-points on   4 processes:     0.1936 ; per K-point          0.0138 ; proc-sec per K-point          0.0553
# time1 =  0.0013942718505859375
# time2 =  0.014590978622436523
# sum of weights now :0.002249999999999997
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 16 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     16 K-points on   4 processes:     0.2388 ; per K-point          0.0149 ; proc-sec per K-point          0.0597
# time1 =  0.0025339126586914062
# time2 =  0.020923137664794922
# sum of weights now :0.002249999999999997
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 16 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     16 K-points on   4 processes:     0.2147 ; per K-point          0.0134 ; proc-sec per K-point          0.0537
# time1 =  0.002411365509033203
# time2 =  0.013494253158569336
# sum of weights now :0.00225
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 16 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     16 K-points on   4 processes:     0.2260 ; per K-point          0.0141 ; proc-sec per K-point          0.0565
# time1 =  0.0016875267028808594
# time2 =  0.01764225959777832
# sum of weights now :0.0022500000000000007
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 16 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     16 K-points on   4 processes:     0.2614 ; per K-point          0.0163 ; proc-sec per K-point          0.0653
# time1 =  0.002531766891479492
# time2 =  0.015973329544067383
# sum of weights now :0.0022500000000000007
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 14 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     14 K-points on   4 processes:     0.1987 ; per K-point          0.0142 ; proc-sec per K-point          0.0568
# time1 =  0.0013394355773925781
# time2 =  0.015311956405639648
# sum of weights now :0.0022500000000000024
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 16 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     16 K-points on   4 processes:     0.2172 ; per K-point          0.0136 ; proc-sec per K-point          0.0543
# time1 =  0.0016567707061767578
# time2 =  0.016144990921020508
# sum of weights now :0.0022500000000000033
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 16 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     16 K-points on   4 processes:     0.2067 ; per K-point          0.0129 ; proc-sec per K-point          0.0517
# time1 =  0.0014913082122802734
# time2 =  0.014505147933959961
# sum of weights now :0.0022500000000000037
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 16 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     16 K-points on   4 processes:     0.2133 ; per K-point          0.0133 ; proc-sec per K-point          0.0533
# time1 =  0.0015926361083984375
# time2 =  0.016475439071655273
# sum of weights now :0.0022500000000000033
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 12 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     12 K-points on   4 processes:     0.1495 ; per K-point          0.0125 ; proc-sec per K-point          0.0498
# time1 =  0.0011553764343261719
# time2 =  0.015295743942260742
# sum of weights now :0.0022500000000000037
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 16 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     16 K-points on   4 processes:     0.1955 ; per K-point          0.0122 ; proc-sec per K-point          0.0489
# time1 =  0.0015151500701904297
# time2 =  0.015703916549682617
# sum of weights now :0.0022500000000000037
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 16 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     16 K-points on   4 processes:     0.2796 ; per K-point          0.0175 ; proc-sec per K-point          0.0699
# time1 =  0.001474142074584961
# time2 =  0.014835357666015625
# sum of weights now :0.002250000000000004
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 16 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     16 K-points on   4 processes:     0.2108 ; per K-point          0.0132 ; proc-sec per K-point          0.0527
# time1 =  0.0016453266143798828
# time2 =  0.019453763961791992
# sum of weights now :0.0022500000000000033
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 16 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     16 K-points on   4 processes:     0.2177 ; per K-point          0.0136 ; proc-sec per K-point          0.0544
# time1 =  0.0015218257904052734
# time2 =  0.015052318572998047
# sum of weights now :0.0022500000000000037
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 16 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     16 K-points on   4 processes:     0.1937 ; per K-point          0.0121 ; proc-sec per K-point          0.0484
# time1 =  0.0015153884887695312
# time2 =  0.01630997657775879
# sum of weights now :0.0022500000000000033
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 12 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     12 K-points on   4 processes:     0.1582 ; per K-point          0.0132 ; proc-sec per K-point          0.0527
# time1 =  0.0018529891967773438
# time2 =  0.018259525299072266
# sum of weights now :0.0022500000000000033
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 14 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     14 K-points on   4 processes:     0.2416 ; per K-point          0.0173 ; proc-sec per K-point          0.0690
# time1 =  0.001707315444946289
# time2 =  0.01667022705078125
# sum of weights now :0.0022500000000000037
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 14 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     14 K-points on   4 processes:     0.1888 ; per K-point          0.0135 ; proc-sec per K-point          0.0540
# time1 =  0.0013918876647949219
# time2 =  0.015539407730102539
# sum of weights now :0.0022500000000000037
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 16 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     16 K-points on   4 processes:     0.2012 ; per K-point          0.0126 ; proc-sec per K-point          0.0503
# time1 =  0.0024118423461914062
# time2 =  0.0158078670501709
# sum of weights now :0.0022500000000000046
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 16 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     16 K-points on   4 processes:     0.1993 ; per K-point          0.0125 ; proc-sec per K-point          0.0498
# time1 =  0.0016739368438720703
# time2 =  0.0169832706451416
# sum of weights now :0.0022500000000000046
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 14 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     14 K-points on   4 processes:     0.2776 ; per K-point          0.0198 ; proc-sec per K-point          0.0793
# time1 =  0.0013852119445800781
# time2 =  0.015872955322265625
# sum of weights now :0.002250000000000004
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 16 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     16 K-points on   4 processes:     0.2224 ; per K-point          0.0139 ; proc-sec per K-point          0.0556
# time1 =  0.0014657974243164062
# time2 =  0.015411853790283203
# sum of weights now :0.0022500000000000046
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 16 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     16 K-points on   4 processes:     0.1925 ; per K-point          0.0120 ; proc-sec per K-point          0.0481
# time1 =  0.0015223026275634766
# time2 =  0.014525175094604492
# sum of weights now :0.002250000000000004
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 16 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     16 K-points on   4 processes:     0.2024 ; per K-point          0.0127 ; proc-sec per K-point          0.0506
# time1 =  0.0024352073669433594
# time2 =  0.014861822128295898
# sum of weights now :0.002250000000000004
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 16 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     16 K-points on   4 processes:     0.2123 ; per K-point          0.0133 ; proc-sec per K-point          0.0531
# time1 =  0.0015447139739990234
# time2 =  0.017339229583740234
# sum of weights now :0.0022500000000000046
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 14 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     14 K-points on   4 processes:     0.1839 ; per K-point          0.0131 ; proc-sec per K-point          0.0525
# time1 =  0.0022203922271728516
# time2 =  0.015014886856079102
# sum of weights now :0.002250000000000005
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 16 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     16 K-points on   4 processes:     0.1971 ; per K-point          0.0123 ; proc-sec per K-point          0.0493
# time1 =  0.0025212764739990234
# time2 =  0.016865968704223633
# sum of weights now :0.002250000000000006
# Writing file_Klist_factor_changed to Klist_ahc.changed_factors.txt
# symgroup : <wannierberri.symmetry.Group object at 0x7f91c33ef190>
# processing 16 K points : using  4 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# time for processing     16 K-points on   4 processes:     0.2169 ; per K-point          0.0136 ; proc-sec per K-point          0.0542
# time1 =  0.002476215362548828
# Totally processed 879 K-points

# %%
#plot results from different iterations

#for i in range(0,11,2):
for l in 300,:
    for i in 30,:
        for grid in [ "tetragonal",
                "parallel",
               # "trigonalH-0.1",
                "trigonalH-0.15",
                "trigonalH-0.25",
                ]:
            try:
#                a = np.loadtxt(f"Te-dos-{grid}-{l}_iter-{i:04d}.dat")
                a = np.loadtxt(f"Te-cumdos-{grid}-{l}_iter-{i:04d}.dat")
                plt.plot(a[:,0],a[:,1],label = f"{grid}-{i}-{l}-cumdos")
             #   plt.plot(a[:,0],a[:,1]-a[-1,1],label = f"{grid}-{i}-{l}-xx")
             #   a = np.loadtxt(f"Te-BD_sea-{grid}-{l}_iter-{i:04d}.dat")
             #   a = np.loadtxt(f"Te-BD_sea_hole-{grid}-{l}_iter-{i:04d}.dat")
             #   plt.plot(a[:,0],a[:,1]-a[-1,1],label = f"{grid}-{i}-{l}-xx")
             #   plt.plot(a[:,0],a[:,5]-a[-1,5],label = f"{grid}-{i}-{l}-yy")
             #   plt.plot(a[:,0],a[:,9]-a[-1,9],label = f"{grid}-{i}-{l}-zz")
             #   plt.plot(a[:,0],a[:,1]+a[:,9]+a[:,5],label = f"{grid}-{i}-{l}-trace")
             #   a = np.loadtxt(f"Te-BD_sea_hole-{grid}-{l}_iter-{i:04d}.dat")
             #   plt.plot(a[:,0],a[:,1]-a[-1,1],"--",label = f"{grid}-{i}-{l}-xx")
             #   plt.plot(a[:,0],a[:,5]-a[-1,5],"--",label = f"{grid}-{i}-{l}-yy")
             #   plt.plot(a[:,0],a[:,9]-a[-1,9],"--",label = f"{grid}-{i}-{l}-zz")
             #   plt.plot(a[:,0],a[:,1]+a[:,9]+a[:,5],"--",label = f"{grid}-{i}-{l}-trace")
                
            except:
                pass
            
            

#plt.ylim(-1000,1000)

plt.legend()

plt.show()

# %%
# !ls Te-dos-parallel*iter-0030.dat
# Out:
# Te-dos-parallel-100_iter-0030.dat  Te-dos-parallel-300_iter-0030.dat
# Te-dos-parallel-200_iter-0030.dat
